# %% [markdown]
# ### Import useful libraries

# %%
import random
from datetime import datetime
from tqdm import trange
from board import Board
from player import Player
from utils import *

# %% [markdown]
# ### Test if the player learned the optimal strategy

# %%
me     = 'o'
agent  = 'x'

board  = Board(nrow=3, ncol=3, sign_play=[agent,me])
player = Player(sign=agent, order=float('inf'))

# %%
# board.add(sign='o', row=0, col=0)
# board.add(sign='x', row=1, col=1)
# board.add(sign='o', row=2, col=2)
# board.add(sign='x', row=0, col=1)

# board.print()
# print(board.get_state())
# print(board.get_next_states(sign=agent))

a, N, Q = player.choose_action_mcts(board, num_sim=10**6, return_dicts=True)

# N = {}
# Q = {}
# P = {}
# c = 1
# N, Q = player.mcts_simulation(board, N, Q, P, c)
# Out:
# 100%|██████████| 1000000/1000000 [2:44:39<00:00, 101.22it/s]

# %%
save_dict(data=Q, file_name="data/mcts-Q-1000000")
save_dict(data=N, file_name="data/mcts-N-1000000")

# %%
import math
P = {}
c = 1

# %%
random.seed(100)

# play on a copy of the board
board_cpy = copy.deepcopy(board)
# store all the states of this MCTS simulation
board_states = []

# assume that the game will be a draw
reward = 0.5
while not board_cpy.is_full():

    # update visit count (necessary because of self-play = inverse board)
    N[board_cpy.get_state()] = N.get(board_cpy.get_state(), 0) + 1

    # evaluate possible actions
    next_states = board_cpy.get_next_states(sign=agent)
    ucb_state   = []
    for state in next_states:
#         print("")
#         print(state)
        q  = Q.get(state, 0.5)
        p  = P.get(state, 1/len(next_states))
        na = N.get(state, 0)
        nb = N.get(board_cpy.get_state())
#         print('ratio           = ', math.sqrt(nb) / (1+na))
#         print('num next states = ', len(next_states))
#         print('N(s,a)          = ', na)
        ucb_state.append(q + c * p * math.sqrt(nb) / (1+na))

    print(["{0:0.10f}".format(v) for v in ucb_state])

    # select action that maximizes the UCB value
    action = random.choices(board_cpy.get_free_positions(), weights=normalize(ucb_state, 5))[0]
#     action = random.choices(board_cpy.get_free_positions(), weights=normalize(ucb_state, float('inf')))[0]
    # take action
    board_cpy.add(sign=agent, row=action[0], col=action[1])
    
    board_cpy.print()
    
    # update visit count
    N[board_cpy.get_state()] = N.get(board_cpy.get_state(), 0) + 1
    # add board state to list of visited states
    board_states.append(board_cpy.get_state())

    # check if player won
    if board_cpy.is_won(): 
        reward = 1
        break
    # if nobody won yet, inverse the board
    board_cpy.inverse()
# Out:
# ['0.5033397155', '0.5033303513', '0.5033278869', '0.5033303493', '0.5033298234', '0.5033259254', '0.5033303858', '0.5033303493', '0.5033303432']
#
#  x - -
#  - - -
#  - - -
# ['0.4975853495', '0.4707377071', '0.4990018264', '0.5022875662', '0.5008225714', '0.4946384147', '0.4969784418', '0.4991832479']
#
#  o - -
#  - x -
#  - - -
# ['0.5008247948', '0.4991169679', '0.5007832216', '0.5008021714', '0.4886066180', '0.5008219737', '0.5006111639']
#
#  x x -
#  - o -
#  - - -
# ['0.5104387560', '0.5098797155', '0.5102564683', '0.5092206018', '0.5100964276', '0.5098797155']
#
#  o o x
#  - x -
#  - - -
# ['0.4951249631', '0.4951249631', '0.4998437795', '0.4951249631', '0.4951249631']
#
#  x x o
#  - o -
#  x - -
# ['0.5085656611', '0.5004061860', '0.3430008865', '0.5057092163']
#
#  o o x
#  x x -
#  o - -
# ['0.5029285032', '0.5016525977', '0.5017299253']
#
#  x x o
#  o o x
#  x - -
# ['0.5016460245', '0.5011898925']
#
#  o o x
#  x x o
#  o x -
# ['0.5051220678']
#
#  x x o
#  o o x
#  x o x

# %%
# next possible states
next_states = board.get_next_states(sign=agent)    
# get count for each next state
next_counts = [N.get(state, 0) for state in next_states]
# randomly select action according to weights in next_counts
print(normalize(next_counts, 1))
print(next_states)
# Out:
# [0.04899506909368722, 0.06684173000712987, 0.12458463289197505, 0.05242900384892687, 0.45335238630466024, 0.07098965119662727, 0.11263086001365974, 0.04912606660473451, 0.021050600038599265]
# ['x--------', '-x-------', '--x------', '---x-----', '----x----', '-----x---', '------x--', '-------x-', '--------x']

# %%
Q
# Out:
# {'-xxooxo-x': 1.0,
#  '-o-xxox-o': 0.0,
#  '-x--oxo-x': 0.6,
#  '-o--x-x-o': 0.026315789473684223,
#  '-x--o---x': 0.498323085522639,
#  '----x---o': 0.5026752164090509,
#  '--------x': 0.49805234905705065,
#  '-ox-xoxox': 1.0,
#  '-xo-ox-xo': 0.0,
#  '-ox-x--ox': 1.0,
#  '-xo----xo': 0.06666666666666667,
#  '--x----ox': 0.9814814814814815,
#  '-------xo': 0.0,
#  'xxo-xoo-x': 1.0,
#  '-ox-oxx-o': 0.0,
#  '-x--xoo-x': 0.8552631578947368,
#  '-o---xx-o': 0.0,
#  '-x---o--x': 0.6666666666666667,
#  '-----x--o': 0.1875,
#  'xoo-x---x': 1.0,
#  'oxx-----o': 0.0,
#  'x-o-----x': 0.5,
#  '--x-----o': 0.0,
#  'xooooxxxx': 1.0,
#  'oxxxxo-oo': 0.0,
#  'xo-oox-xx': 1.0,
#  'ox-xx--oo': 0.0,
#  'xo-o---xx': 1.0,
#  '-x-x---oo': 0.0,
#  '-o-----xx': 0.9166666666666667,
#  '-x------o': 0.1,
#  'ooxoxxxox': 1.0,
#  'xx-xoooxo': 0.0,
#  '-o-oxxxox': 1.0,
#  '-x-xoo-xo': 0.0,
#  '---oxx-ox': 0.875,
#  '---x-o-xo': 0.0,
#  '---o-x--x': 0.5888888888888889,
#  '---x----o': 0.0,
#  'oxxxooxox': 0.5,
#  'x-ooxxoxo': 0.5,
#  'o-xx-oxox': 0.5,
#  'x-oo-x-xo': 0.5,
#  'o-xx-o--x': 0.5,
#  'x--o-x--o': 0.5,
#  'o--x----x': 0.5,
#  'x-------o': 0.2419354838709678,
#  '--xxoxoox': 1.0,
#  '---oxoxxo': 0.0,
#  '---x-xoox': 0.8333333333333334,
#  '-----oxxo': 0.0,
#  '-----xo-x': 0.8941176470588231,
#  '------x-o': 0.0,
#  'oox-o-xxx': 1.0,
#  'xxo-x--oo': 0.0,
#  'oox----xx': 0.8333333333333334,
#  'xxo-----o': 0.0,
#  'o-x-----x': 0.9499999999999997,
#  'oxxxoooxx': 0.5,
#  'x-ooxxxoo': 0.5,
#  'o-xxo-oxx': 0.5002868617326438,
#  'x-o-x-xoo': 0.05,
#  'o-x---oxx': 0.07142857142857144,
#  'x-o---x-o': 0.12710280373831773,
#  'o-xooxx-x': 1.0,
#  'x-oxx-o-o': 0.0,
#  'o-xo--x-x': 0.8888888888888888,
#  'x-ox----o': 0.0,
#  'xoo-xxoxo': 0.5,
#  'oxx-o-xox': 0.5041392285983063,
#  'xoo-x--xo': 0.004901960784313731,
#  'oxx----ox': 0.5,
#  'x-o----xo': 0.038461538461538464,
#  'oxxoxoxox': 1.0,
#  'xo-xoxoxo': 0.0,
#  'ox-ox-xox': 0.5625,
#  'x--xo-oxo': 0.0,
#  'o---x-xox': 0.5,
#  'x---o--xo': 0.0,
#  'o---x---x': 0.7692307692307693,
#  'oxoo-oxxx': 1.0,
#  'xoxx-xo-o': 0.0,
#  '-xoo-ox-x': 1.0,
#  '-oxx-xo--': 0.0,
#  '-xo--ox--': 0.5000000000000001,
#  '-ox--x---': 0.0,
#  '-x---o---': 0.24099337249417702,
#  '-----x---': 0.5017607865785787,
#  'xoxox-xoo': 1.0,
#  'oxoxo--xx': 0.0,
#  'xoxox---o': 0.514096968267077,
#  'ox-xo---x': 0.48837612768910477,
#  'xo--x---o': 0.49325337331334357,
#  '-o--x----': 0.5008397513117947,
#  '-x-------': 0.5016680879074903,
#  'oo-xxxo--': 1.0,
#  'xx-o-ox--': 0.0,
#  'oo-x-x---': 0.5,
#  'xx-o-----': 0.0,
#  'o--x-----': 0.20148784660291116,
#  'x--------': 0.5010719317230495,
#  'xxooxoxox': 1.0,
#  '-oxxoxoxo': 0.0,
#  '-xooxox-x': 1.0,
#  '-oxxoxo--': 0.0,
#  '-x-oxox--': 0.5,
#  '---xoxo--': 0.0,
#  '----xox--': 0.8387096774193548,
#  '-----xo--': 0.1130030959752321,
#  '------x--': 0.502343895661128,
#  'xxxooxxoo': 1.0,
#  '-ooxxooxx': 0.0,
#  '-xxo-xxoo': 1.0,
#  '-oox--oxx': 0.0,
#  '-xxo--x-o': 1.0,
#  '-o-x--o-x': 0.0,
#  '-x-o--x--': 0.55,
#  '---x--o--': 0.10625000000000004,
#  '-o--o-xxx': 1.0,
#  '-x--x-oo-': 0.0,
#  '----o-xx-': 0.4900325467860064,
#  '----x-o--': 0.5047530780892631,
#  'oo-xxooxx': 0.0,
#  'xx--oxxoo': 1.0,
#  '-o--xooxx': 0.11111111111111113,
#  '-x--oxxo-': 0.4950657894736844,
#  '----xoox-': 0.5154519990139376,
#  '-----xxo-': 0.6415094339622642,
#  '------ox-': 0.11578947368421057,
#  'xxxooxoo-': 1.0,
#  'o-oxxoxx-': 0.0,
#  'x-xo-xoo-': 0.5,
#  'o--x-oxx-': 0.0,
#  'x----xoo-': 0.13777777777777778,
#  'o-----xx-': 0.9047619047619045,
#  'x-----o--': 0.11749241658240654,
#  'oox-xoxx-': 1.0,
#  'xxo--xoo-': 0.0,
#  'o-x--oxx-': 0.6666666666666667,
#  '-----oxx-': 0.6666666666666666,
#  '-----x-o-': 0.0,
#  '-------x-': 0.5010686587823406,
#  'oxo-xoxx-': 1.0,
#  'xox--xoo-': 0.0,
#  '-xo--oxx-': 0.5,
#  '-ox--x-o-': 0.0,
#  '-xo----x-': 0.75,
#  '--x----o-': 0.0,
#  'xxxooxoxo': 1.0,
#  'oo-xxoxox': 0.0,
#  'xx-oox-xo': 0.5160213618157539,
#  '-o-xxo-ox': 0.48502994011976075,
#  '-x-o-x-xo': 0.5573770491803283,
#  '-o-x---ox': 0.0,
#  '-x-o---x-': 0.33333333333333337,
#  '---x---o-': 0.0,
#  'xoxoxoxo-': 1.0,
#  'oxoxox-x-': 0.0,
#  'xoxox--o-': 1.0,
#  'ox-xo--x-': 0.0,
#  'x--ox--o-': 0.1607142857142857,
#  'o--x---x-': 0.0,
#  'x------o-': 0.1998320028713302,
#  'oxo-x-oxx': 1.0,
#  'x-x-o-xoo': 0.0,
#  'o---x-oxx': 0.005813953488372101,
#  'x---o-x-o': 0.4997340862985897,
#  'x---o----': 0.20298507462686563,
#  '----x----': 0.5030847382108254,
#  '--x-xox-o': 1.0,
#  '----oxo-x': 0.0,
#  '----ox---': 0.02083333333333333,
#  '--xoxxxoo': 1.0,
#  '--oxoo-xx': 0.0,
#  '--xoxx-o-': 1.0,
#  '--oxo--x-': 0.0,
#  '--x-x--o-': 0.9545454545454544,
#  '----o--x-': 0.0,
#  'xxx-o-o-o': 1.0,
#  '-oo-x-x-x': 0.0,
#  '-xx-o-o--': 0.1447368421052631,
#  '--o-x-x--': 0.7,
#  '--x-o----': 0.26600167410714304,
#  'xoxxoxoxo': 0.5,
#  'oxooxox-x': 0.5,
#  'xoxxoxo--': 0.008333333333333338,
#  'oxoox-x--': 0.5070493454179222,
#  'xoxxo----': 0.007462686567164183,
#  'ox-ox----': 0.046875000000000014,
#  'x--xo----': 0.4969824984912481,
#  '---ox----': 0.5007543307848363,
#  '---x-----': 0.5012111386610694,
#  '--x-xoxo-': 1.0,
#  '--o-ox-x-': 0.0,
#  '--x-xo---': 0.8518518518518516,
#  '--o--x---': 0.13333333333333328,
#  '--x------': 0.5024360487049215,
#  'xoxox-o-x': 1.0,
#  'oxoxo-x--': 0.0,
#  'xoxox----': 0.875,
#  'oxox-----': 0.10416666666666666,
#  'xox------': 0.7142857142857143,
#  '-xo------': 0.11731927710843375,
#  'o-oxxooxx': 0.0,
#  'x-xooxxo-': 0.02702702702702704,
#  '--oxxoox-': 0.0,
#  '--xo-xxo-': 1.0,
#  '--ox--ox-': 0.0,
#  '--xo--x--': 0.625,
#  '--ox-----': 0.026881720430107527,
#  'x-xoxoo-x': 1.0,
#  '--oxoxx-o': 0.0,
#  '--xox-o-x': 0.25,
#  '--oxo-x--': 0.02873563218390804,
#  '--x-x-o--': 0.5027732410536758,
#  '--o---x--': 0.0,
#  'xoox-xoxo': 0.0,
#  'oxxo-ox-x': 0.5,
#  'xoox-x--o': 0.0,
#  'oxx--o--x': 0.5,
#  'x-o--x--o': 0.0,
#  'x-o------': 0.03191489361702127,
#  '-ox-xxxoo': 1.0,
#  '-xo-oo-xx': 0.0,
#  '--x-xx-oo': 0.10000000000000002,
#  '--o-o--xx': 0.0,
#  '--o----x-': 0.051020408163265314,
#  '-xooxooxx': 1.0,
#  '-oxx-xxoo': 0.0,
#  '-xoo--oxx': 0.1388888888888889,
#  '--xx--xoo': 0.0,
#  '--oo---xx': 1.0,
#  '--xx----o': 0.0,
#  '--o-----x': 0.09259259259259263,
#  'xoxoxxxoo': 1.0,
#  'oxoxoo-xx': 0.0,
#  'x-xoxx-oo': 0.11111111111111113,
#  'o-oxo--xx': 0.0,
#  'x-xox---o': 0.8333333333333334,
#  '--oxo---x': 0.07142857142857144,
#  '--x-x---o': 0.8867924528301887,
#  'oxo-x--xo': 1.0,
#  'x-x-o--ox': 0.0,
#  '--o-x--xo': 0.06250000000000003,
#  '--x-o---x': 0.49500460102537164,
#  '--o-x----': 0.4990917190717493,
#  'o-xoxox-x': 1.0,
#  'x--xoxo-o': 0.0,
#  'o--ox-x-x': 0.5,
#  'x--xo---o': 0.0,
#  'xxxooxo-o': 1.0,
#  'oo-xxox-x': 0.0,
#  'xx--oxo-o': 0.2,
#  'o---xox-x': 0.0,
#  'x---ox--o': 0.375,
#  'xxxoo-oox': 1.0,
#  'oo-xx-xxo': 0.0,
#  'xx-oo-o-x': 0.06111111111111114,
#  'oo-xx-x--': 0.0,
#  'xx--o-o--': 0.12500000000000006,
#  'o---x-x--': 0.8088235294117645,
#  '-xx-o---o': 0.0,
#  '--o-x---x': 0.5,
#  'xox-o-x-o': 0.0,
#  '-xo-x-o-x': 1.0,
#  '--x-o-x-o': 0.008353569694026227,
#  'xoo-xx-ox': 1.0,
#  'oxx-oo-x-': 0.0,
#  'xoo-xx---': 0.9166666666666667,
#  '-xx-oo---': 0.1,
#  '-o--xx---': 0.9224137931034483,
#  '-x--o----': 0.1906779661016949,
#  'xoxxxooxo': 0.5,
#  '-xoooxxox': 0.5,
#  '--xxxooxo': 0.5,
#  '--oooxx-x': 0.5071910112359536,
#  '--xxxoo--': 0.49302930056710786,
#  '--o-oxx--': 0.4571690503126623,
#  '----o-x--': 0.49228144954072817,
#  'o-xox-xxo': 1.0,
#  'x-ox--oox': 0.0,
#  'o-x---xxo': 0.5,
#  'x-o----ox': 0.3636363636363637,
#  'o-x----x-': 0.6666666666666667,
#  'oox--xoxx': 1.0,
#  'xxo---xoo': 0.0,
#  '-ox---oxx': 0.5714285714285715,
#  '-x----xoo': 0.0,
#  '-x-----o-': 0.0,
#  'x-xooxoox': 1.0,
#  'o--xxoxxo': 0.0,
#  'x---oxoox': 0.08333333333333334,
#  '----xoxxo': 0.0,
#  '----ox-ox': 0.3888888888888889,
#  '----x--xo': 0.9344262295081968,
#  '-------ox': 0.30357142857142866,
#  'o-oxooxxx': 1.0,
#  'x-xoxxo-o': 0.0,
#  'o-oxo-x-x': 0.25000000000000006,
#  'x-xox-o--': 0.9711538461538461,
#  'o--xo-x--': 0.33333333333333337,
#  'x--ox----': 0.0,
#  '---xo----': 0.24113142292490125,
#  'xo-x-ox--': 1.0,
#  'ox-o-x---': 0.0,
#  'x--x-o---': 0.625,
#  '---o-x---': 0.0,
#  'xooxxxoxo': 1.0,
#  'oxxoo-xox': 0.0,
#  'xooxx-ox-': 1.0,
#  'oxxoo-x--': 0.0,
#  'xooxx----': 0.6666666666666667,
#  'oxxo-----': 0.08163265306122451,
#  'xo-x-----': 0.6666666666666667,
#  '-x-o-----': 0.0,
#  'ooxxxooxx': 0.5,
#  'xxoooxxo-': 0.5,
#  '-oxxxoox-': 0.5,
#  '-xoo-xxo-': 0.5,
#  '-oxx--ox-': 0.5,
#  '-x-o--xo-': 0.44594594594594594,
#  '---x--ox-': 0.5243445692883894,
#  '---o--x--': 0.40468227424749165,
#  'x--xo-x-o': 1.0,
#  '---ox-o-x': 0.13043478260869565,
#  '---x--x-o': 0.9042553191489356,
#  '---o----x': 0.05859375,
#  '--xooxo-x': 1.0,
#  '--oxx-x-o': 0.0,
#  '--xoo---x': 0.6363636363636364,
#  '--oxx----': 0.6,
#  '--xo-----': 0.16428571428571428,
#  'oo-xxx-ox': 1.0,
#  'xx--oo-xo': 0.0,
#  'oo--xx--x': 0.5,
#  'xx---o--o': 0.0,
#  'o----x--x': 0.5,
#  'o-xoxx-ox': 1.0,
#  'x--xoo-xo': 0.0,
#  'o---xx-ox': 0.6666666666666667,
#  'x----o-xo': 0.07407407407407407,
#  'xo-xxoxoo': 1.0,
#  'ox-oox-xx': 0.0,
#  'x--xxo-oo': 0.10000000000000002,
#  'o---ox-xx': 0.9310344827586206,
#  'x---xo--o': 0.051527419948472576,
#  'ooxxooxxx': 1.0,
#  'xxooxxoo-': 0.0,
#  '-oxxooxx-': 1.0,
#  '-xooxxo--': 0.0,
#  '-oxxo-x--': 0.014492753623188415,
#  '-xoox----': 0.5018011018505489,
#  '--xxo----': 0.5008768119439423,
#  'xoxxo-x-o': 1.0,
#  '-xoox-o-x': 0.0,
#  '--xxo-x-o': 0.33333333333333337,
#  '--oox---x': 0.011904761904761906,
#  'xxxox-o-o': 1.0,
#  '-ooxo-x-x': 0.0,
#  '-xx-x-o-o': 0.03389830508474578,
#  '--o-o-x-x': 0.497964414957783,
#  'xoxxoooxx': 0.5,
#  '-xooxxxoo': 0.5,
#  '--xxoooxx': 0.5,
#  '--ooxxx-o': 0.49305211918449837,
#  '--xxo-o-x': 0.5151888341543497,
#  '--oox-x--': 0.48879310344827537,
#  'x-xxooxo-': 1.0,
#  'o-ooxx-x-': 0.0,
#  'x-xxoo---': 0.9870129870129871,
#  '--ooxx---': 0.02325581395348838,
#  'xxooxx-oo': 0.0,
#  'o-xxoo-xx': 0.5014985954867468,
#  'x-ooxx-o-': 0.5006469874646156,
#  'o-xxo--x-': 0.04166666666666667,
#  'x-oox----': 0.4909277143693297,
#  'oxx-xox-o': 1.0,
#  'xoo-ox--x': 0.0,
#  'oxx-x---o': 0.9642857142857142,
#  'x-o-o---x': 0.0,
#  '-xoox--xo': 1.0,
#  '--xxo--ox': 0.0,
#  '--oox--x-': 0.5011663507799965,
#  'xooxx-xoo': 1.0,
#  'oxxoo--xx': 0.0,
#  'xo-xx--oo': 0.33333333333333337,
#  'ox--o--xx': 0.08333333333333334,
#  'ox------x': 0.0,
#  'xxx-oo-xo': 1.0,
#  '-oo-xx-ox': 0.0,
#  '-xx-oo-x-': 0.008403361344537823,
#  '--o-xx-o-': 0.5006978367062025,
#  '--x-o--x-': 0.5013079109713313,
#  'xooxx-oox': 1.0,
#  '-xxoo-xxo': 0.0,
#  '--oxx-oox': 1.0,
#  '--xoo-xx-': 0.0,
#  '--oxx--o-': 0.4987771558892445,
#  'xxxoxooxo': 1.0,
#  'o-oxoxxox': 0.0,
#  'x-xoxo-xo': 1.0,
#  '--oxox-ox': 0.0,
#  '--x-xo-xo': 0.9615384615384616,
#  '--o--x-ox': 0.0,
#  '--x----xo': 0.5937500000000001,
#  'o-xoxxxoo': 1.0,
#  'x--xoooxx': 0.0,
#  'o---xxxoo': 1.0,
#  'x----ooxx': 0.0,
#  'o----xxo-': 0.3935185185185185,
#  'x-----ox-': 0.5357781753130592,
#  '------xo-': 0.4846062759029014,
#  'oxooxxxox': 0.5,
#  'x-xxoooxo': 0.5,
#  'o--oxxxox': 0.5,
#  'x--xooox-': 0.25,
#  '---oxxxo-': 0.5,
#  '---xo-ox-': 0.06250000000000001,
#  '---ox-x--': 0.9113475177304963,
#  'xxxoo-xoo': 1.0,
#  'oo-xx-oxx': 0.0,
#  'xx--o-xoo': 1.0,
#  'x-----xoo': 0.7822580645161291,
#  'o------xx': 0.0,
#  'xoxxoox--': 1.0,
#  'oxo-xxo--': 0.0,
#  'xox-o-x--': 0.02777777777777779,
#  'oxo-x----': 0.513727924944815,
#  'x-x-o----': 0.4948467588825612,
#  'o-ooxoxxx': 1.0,
#  'x-xxoxoo-': 0.0,
#  'o-oox-xx-': 0.10909090909090911,
#  'x-xxo--o-': 0.0,
#  'o-o-x--x-': 0.15669515669515668,
#  'o-xo-x-ox': 1.0,
#  'x-ox---xo': 0.0,
#  '--xo---ox': 0.8571428571428572,
#  '--ox---x-': 0.0,
#  'oxxooxxox': 1.0,
#  'xooxxoox-': 0.0,
#  'oxx-oxxo-': 0.021739130434782622,
#  'xo--xoox-': 0.5084400136165689,
#  'ox--oxx--': 0.0625,
#  'x---xoo--': 0.06666666666666668,
#  'o----xx--': 0.5,
#  'xoxx-oxo-': 1.0,
#  'oxo--xox-': 0.08333333333333334,
#  'xox---xo-': 0.5,
#  'ox----ox-': 0.030303030303030304,
#  'xo----x--': 0.9222614840989399,
#  '-x----o--': 0.11300309597523221,
#  'xxx-oooox': 1.0,
#  'oo--xxxxo': 0.0,
#  'xx--ooo-x': 0.05592105263157896,
#  'o---xxx-o': 0.9545454545454544,
#  'x----oo-x': 0.2258064516129033,
#  '-o-oxoxxx': 1.0,
#  '-x-xox-oo': 0.0,
#  '---oxo-xx': 1.0,
#  '---xox-o-': 0.0,
#  '---ox--x-': 0.9459459459459459,
#  '-ox-x-x-o': 1.0,
#  '-xo-o---x': 0.0,
#  '----o---x': 0.2319587628865979,
#  'x-xox-oox': 1.0,
#  'o-oxo-xx-': 0.0,
#  'x-x-x-oo-': 0.5,
#  '--o-o-xx-': 0.09708737864077668,
#  'ooxoxxxxo': 1.0,
#  'xx-xoooox': 0.0,
#  'oo-oxxxx-': 0.5,
#  'xx-xo-oo-': 0.2,
#  'o--ox-xx-': 0.8571428571428572,
#  'x--xo--o-': 0.0,
#  'xxx-oo--o': 1.0,
#  'o-o-xx--x': 0.0,
#  'x-x-o---o': 0.5666666666666667,
#  'oox-ox--x': 1.0,
#  'xxo-x---o': 0.0,
#  'o-x-o---x': 1.0,
#  'x-o-x----': 0.0,
#  'xooxxoo-x': 1.0,
#  '-xxooxx-o': 0.0,
#  '-ooxx-o-x': 0.375,
#  '-xxoo-x--': 0.01818181818181819,
#  '--oxx-o--': 0.5049013455682645,
#  '--x-o-x--': 0.497771612408134,
#  'o-x-ooxxx': 1.0,
#  'x-o-xxo-o': 0.028571428571428584,
#  'o-x--ox-x': 0.9642857142857143,
#  'x----xo-o': 0.05681818181818183,
#  'o-----x-x': 0.926300578034682,
#  'o-xox-xox': 1.0,
#  'x-ox--oxo': 0.0,
#  'x--x--o-o': 0.06730769230769235,
#  'oox-oxx-x': 1.0,
#  'xx--xoo-o': 0.0,
#  'oo---xx-x': 0.5,
#  'xx----o-o': 0.07017543859649127,
#  'ox-oo-xxx': 1.0,
#  'xo-xx-o-o': 0.032258064516129045,
#  'ox--o-x-x': 0.5096327513546067,
#  'x---x-o-o': 0.0,
#  'oxoxxoxox': 0.5,
#  'x-xooxoxo': 0.5,
#  'o--xxoxox': 0.625,
#  'x---oxoxo': 0.14285714285714288,
#  'x-----oxo': 0.09821428571428575,
#  'o-o---xxx': 1.0,
#  'x-x---o-o': 0.07377049180327871,
#  'xxxoo-oxo': 1.0,
#  'o-oxx-xox': 0.0,
#  'x-x-o-oxo': 0.625,
#  'ooxx-x-ox': 1.0,
#  'xxoo---xo': 0.0,
#  'o-xx---ox': 0.8,
#  'xxo-x-o-o': 0.04168983204918101,
#  'o-x-o-x-x': 1.0,
#  'x-o-x---o': 0.02586206896551724,
#  'oxx--xoox': 1.0,
#  'xoo---xxo': 0.0,
#  'oxx---o-x': 0.5,
#  '-ox--xo-x': 1.0,
#  '-x---ox-o': 0.0,
#  '-oo---xxx': 1.0,
#  '-xx----oo': 0.0,
#  'ooxx-xoxo': 0.0,
#  'xx-o-oxox': 0.5,
#  '-o-x-xoxo': 0.0,
#  '-x-o-ox-x': 0.5,
#  '-o-x-x--o': 0.0,
#  'o-x-oxxox': 1.0,
#  'x-o-x-oxo': 0.02272727272727273,
#  'o-xx-xoox': 1.0,
#  'x-oo--xxo': 0.0,
#  'xoooxxx-o': 0.5,
#  'oxxx-oo-x': 0.5,
#  'xoo--xx-o': 0.625,
#  'o-x--xo-x': 1.0,
#  'oxxxoxoox': 1.0,
#  'xooox-xxo': 0.0,
#  'oxxxo--ox': 0.5029380941687189,
#  'x-oox--xo': 0.0,
#  'ooxo--xxx': 1.0,
#  'xxox--o-o': 0.0,
#  'oxxxxoo-o': 0.0,
#  'xo-ooxx-x': 0.025641025641025654,
#  '-x-xxoo-o': 0.0,
#  '-o-o-xx-x': 1.0,
#  '-x-x-o--o': 0.0,
#  'ooxoxxx-o': 1.0,
#  'xxoxoo--x': 0.0,
#  '-oxoxx--o': 0.06686443485219278,
#  '-xox-o--x': 0.0,
#  '-ox--x--o': 0.33333333333333337,
#  'x-ooxx--o': 0.49633896589713533,
#  '--xxoo--x': 0.49067567567567527,
#  '---oxx--o': 0.2631578947368421,
#  '---x-o--x': 0.5,
#  'oxoxxooxx': 1.0,
#  'xoxooxx-o': 0.0,
#  'oxoxxo--x': 0.75,
#  'x-xoox--o': 0.0,
#  'o--xxo--x': 0.5,
#  '----xo--x': 0.9,
#  '-xooxo-xx': 1.0,
#  '--xxox-oo': 0.0,
#  '---xox--o': 0.0,
#  'xx-oxo-ox': 1.0,
#  '-o-xox-xo': 0.0,
#  '-x--xo-ox': 0.6666666666666666,
#  '----ox-xo': 0.0,
#  'oxooxoxxx': 1.0,
#  'xoxxoxo-o': 0.08333333333333334,
#  '--xxoxo-o': 0.0,
#  '--o-xox-x': 0.9375,
#  '--x-ox--o': 0.0,
#  'xoxo-xo-x': 1.0,
#  'ox-x-ox-o': 0.0,
#  'x--o-xo-x': 0.5,
#  '---x-ox-o': 0.0,
#  'xxo-oxxoo': 0.5,
#  'oox-xo-xx': 0.5,
#  'xxo--x-oo': 0.4090909090909091,
#  'xx-----oo': 0.5,
#  '-o---oxxx': 1.0,
#  '-x---x-oo': 0.0,
#  '-x--x--oo': 0.0,
#  'oxo-xxoxo': 1.0,
#  'x-x-ooxox': 0.0,
#  '--o-xxoxo': 1.0,
#  '--x-oox-x': 0.0,
#  '----xxo-o': 0.25955430576431304,
#  '----o-x-x': 0.4800155975823764,
#  'oxxoox--x': 1.0,
#  'xo-xxo--o': 0.0,
#  'ox--ox--x': 0.5054784514243972,
#  '----ox--x': 0.4972057481751833,
#  'ox-xxooxo': 1.0,
#  'ox-xxo--o': 0.08695652173913049,
#  'x--oox--x': 0.5014829461196226,
#  '---xxo--o': 0.04545454545454546,
#  'oxooxx-xo': 1.0,
#  'xoxxoo--x': 0.0,
#  'oxo-xx--o': 1.0,
#  'x-x-oo--x': 0.0,
#  'o---xx--o': 0.4904891304347827,
#  'x---o---x': 0.4985832957692084,
#  'x--xooxox': 1.0,
#  '---oxxoxo': 0.0,
#  '---xo-xox': 0.032258064516129045,
#  '---ox--xo': 0.4946018893387315,
#  '---xo---x': 0.49651778955337017,
#  'xo-oxoxxo': 0.0,
#  'ox-xoxo-x': 0.03846153846153847,
#  'x--oxox-o': 0.0,
#  '---xoxo-x': 0.10000000000000002,
#  '---ox-x-o': 0.4778067885117489,
#  'xx-oxooxo': 1.0,
#  'o--xoxxox': 0.021739130434782615,
#  'x--ox-oxo': 0.5047910434565326,
#  'o--xo-x-x': 0.4985883844203742,
#  'x--ox---o': 0.035714285714285726,
#  '-ox-oxoxx': 1.0,
#  '-xo-x-xoo': 0.0,
#  '--x-o-oxx': 0.4941248470012243,
#  '----x-xoo': 0.5146917148362232,
#  '----o--xx': 0.4940518677135384,
#  '-x-oo--xx': 0.09523809523809523,
#  '---xx--oo': 0.0,
#  '----ooxxx': 1.0,
#  '----xx-oo': 0.0,
#  'x-o-xx-oo': 0.0,
#  'o-x-o--xx': 1.0,
#  'x---x--oo': 0.0,
#  'ooxxx-xoo': 1.0,
#  'xxooo--xx': 0.0,
#  'o-xxx--oo': 0.5,
#  'x-o-o--xx': 0.0,
#  '--x-x--oo': 0.15517241379310343,
#  'xxoox-oxo': 1.0,
#  'o-xxo-xox': 0.0,
#  'o--x--xox': 0.25,
#  'o-oxxxox-': 1.0,
#  'x-xoo-xo-': 0.0,
#  'o--xx-ox-': 1.0,
#  'x---o-xo-': 0.0,
#  '----x-ox-': 0.5031428135179262,
#  'x--ox-oox': 1.0,
#  'o--xo-xx-': 0.0,
#  'x---x-oo-': 0.17566488537797487,
#  '----x--o-': 0.5004613703195732,
#  '-ox-x-xoo': 1.0,
#  '-xo-o--xx': 0.0,
#  'ooxxoxoxx': 1.0,
#  'xx-oxoxoo': 0.0,
#  'o--xoxoxx': 0.33333333333333337,
#  'x--ox-xoo': 0.0,
#  'o--xo--xx': 0.9705882352941176,
#  'ox-ox--xo': 1.0,
#  'xo-xo---x': 0.0,
#  '-x-ox---o': 0.51062909121047,
#  '--o-o-xxx': 1.0,
#  '-ooxo-xxx': 1.0,
#  '-xxox--oo': 0.0,
#  '--oxo--xx': 0.2,
#  '--xox-xoo': 1.0,
#  '-xxoxoxoo': 1.0,
#  '-ooxox-xx': 0.0,
#  '-xx-xo-oo': 0.32142857142857134,
#  '--o-ox-xx': 0.025641025641025654,
#  'o-oxxxxoo': 1.0,
#  'x-x-oooxx': 0.0,
#  '--o-xxxoo': 0.5101412377009746,
#  '-x--o-oxx': 0.0,
#  'xoo-x-oxx': 1.0,
#  '-xx-o-xoo': 0.0,
#  '-oo-x--xx': 1.0,
#  '-xx-o--o-': 0.0,
#  '--o-x--x-': 0.7272727272727273,
#  'x-oox-oxx': 1.0,
#  'o-xxo-xo-': 0.0,
#  'x-o-x-ox-': 0.9499999999999998,
#  '--x-o-xo-': 0.0,
#  '-xo-xo-x-': 1.0,
#  '--x-ox-o-': 0.0,
#  'xoooxoxxx': 1.0,
#  'oxxxoxoo-': 0.0,
#  'xooox-xx-': 0.6666666666666666,
#  'oxxxo--o-': 0.0,
#  'x-oox--x-': 1.0,
#  '--xxo--o-': 0.25,
#  'x-oxoxxoo': 1.0,
#  '--xoxooxx': 0.0,
#  '--oxoxxo-': 0.41319444444444453,
#  '--xox-ox-': 0.0,
#  '---xo-xo-': 0.188285558636846,
#  'ox-xoooxx': 0.0,
#  'xo-oxxx-o': 0.5227272727272728,
#  'ox-xoo--x': 0.0,
#  'xo-oxx---': 1.0,
#  '-x-xoo---': 0.0,
#  '---oxx---': 0.22222222222222227,
#  'xooxoox-x': 1.0,
#  '-xxoxxo-o': 0.0,
#  '--oxoox-x': 1.0,
#  '--xoxxo--': 0.0,
#  '---xoox--': 0.5141007020091972,
#  'xxxoo----': 1.0,
#  '-ooxx----': 0.0,
#  '-xx-o----': 0.5004210723308655,
#  'xooxxxo-o': 1.0,
#  'oxx-oox-x': 0.0,
#  'xoo-xxo--': 1.0,
#  'oxx-o-x--': 0.0,
#  'xoo-x----': 0.5035844829619194,
#  '--xoox--x': 1.0,
#  '-oxxxoxoo': 1.0,
#  '-xooox-xx': 0.032258064516129045,
#  '-oxxxo--o': 0.5080482897384296,
#  '-xo-ox--x': 0.013157894736842111,
#  '--x-xo--o': 0.5122006993145256,
#  'xo-oxxoxo': 0.5,
#  'ox-xoox-x': 0.5029287341360229,
#  'xo--xxo-o': 0.028320105557321472,
#  '-x-oxo-xo': 1.0,
#  '-o-xox--x': 0.0,
#  'xxooxxoox': 1.0,
#  '-oxxooxxo': 0.0,
#  '-x-oxxoox': 0.08333333333333334,
#  '-o-xo-xxo': 0.017109471415674527,
#  '-x-ox-o-x': 0.4,
#  '-o-xo-x--': 0.0,
#  '-x-ox----': 0.948051948051948,
#  'ooxxoxo-x': 1.0,
#  'xx-oxox-o': 0.0,
#  '-o-xoxo-x': 0.11111111111111113,
#  '-o-xox---': 0.4020512820512821,
#  '-ooxxxxoo': 1.0,
#  '-xx-oooxx': 0.0,
#  '-oo-xxxo-': 0.33333333333333337,
#  '-o--xx-o-': 1.0,
#  '-x--o--x-': 0.0067567567567567615,
#  '-xoxxx-oo': 1.0,
#  '-oxo-o-xx': 0.0,
#  '-xox-x-o-': 0.875,
#  '-oxo---x-': 0.0,
#  '-xox-----': 0.6,
#  'oxoxx--xo': 1.0,
#  'xoxo---ox': 0.0,
#  '-xox---xo': 0.5,
#  '-oxo----x': 0.0,
#  'ox-xxxoo-': 1.0,
#  'xo-o-oxx-': 0.0,
#  'ox-x-xo--': 1.0,
#  'xo-o--x--': 0.0,
#  'ox-x-----': 0.7777777777777778,
#  'x--o-----': 0.19023563597294463,
#  'x--x--xoo': 1.0,
#  '---o--oxx': 0.0,
#  '---x--xo-': 0.9435028248587569,
#  '---o---x-': 0.10416666666666669,
#  'xx-ooxxoo': 0.5,
#  'o--xxooxx': 0.5015446815273917,
#  'x--o-xxoo': 0.45,
#  '---x-ooxx': 0.5,
#  '---o-xx-o': 0.4921645467015837,
#  '---x--o-x': 0.6666666666666666,
#  'oxoooxx-x': 0.5,
#  'xoxxxoo--': 0.5588235294117648,
#  'oxoo-xx--': 0.5,
#  'x-xx-oo--': 0.5,
#  '--oo-xx--': 0.33333333333333337,
#  '--xx--o--': 0.5,
#  'xo-oo-xx-': 0.0,
#  '-x-xx-oo-': 0.03508771929824563,
#  '-o-o--xx-': 0.0,
#  '-x-x--o--': 0.45454545454545464,
#  'xxoxooxox': 1.0,
#  '-oxoxxoxo': 0.0,
#  '-xoxoox-x': 1.0,
#  '-xoxo---x': 0.09090909090909093,
#  '-oxox----': 0.0,
#  'x-ooxo--x': 1.0,
#  'o-xxox---': 0.0,
#  'x--oxo---': 0.7142857142857143,
#  '---xox---': 0.03846153846153848,
#  '-xxoxooxo': 1.0,
#  '--oxoxxox': 0.0,
#  '--xox-oxo': 0.1875,
#  '--oxo-x-x': 0.9411764705882354,
#  '--xox-o--': 0.04411764705882354,
#  '---xo-x--': 0.4948421470271508,
#  '-oxxoxx-o': 0.0,
#  '-xooxo--x': 1.0,
#  '-oxxox---': 0.014492753623188406,
#  '-xo-xo---': 0.038961038961038974,
#  '--x-ox---': 0.5005770340450114,
#  '-x-ooxoxx': 0.0,
#  '---xxoxoo': 0.1739130434782609,
#  '----oxoxx': 0.035714285714285726,
#  'xo-oxxo-x': 1.0,
#  '-x-xoox-o': 0.0,
#  '-o--xxo-x': 0.9411764705882354,
#  '-x--oox--': 0.0,
#  'xoxoxox-o': 1.0,
#  'oxox-xo-x': 0.0,
#  'xox--ox-o': 1.0,
#  'oxo--x--x': 0.0,
#  'x-x--o--o': 1.0,
#  'x----o---': 0.23850490133035118,
#  'xxoooxxox': 0.5,
#  'ooxxxoox-': 0.5,
#  'xx-ooxxo-': 0.5,
#  '-o-xxoox-': 0.06250000000000001,
#  '-o--xo-x-': 0.0625,
#  '-x--ox---': 0.492983250339521,
#  'xxoooxxxo': 0.5,
#  'ooxxxoo-x': 0.5,
#  'xx-ooxx-o': 0.5000993904055144,
#  '-o-xxoo-x': 0.5030005200189539,
#  '-x-ooxx--': 0.5004870781044104,
#  '-o-xx-o--': 0.5052944660137677,
#  '-x--o-x--': 0.4972645831908631,
#  'xoooxxxxo': 0.5,
#  'oxxxooo-x': 0.5,
#  'ox-xo-o-x': 0.07579151732377538,
#  'x--ox-x-o': 0.33333333333333337,
#  'o--x--o-x': 0.06255716114871049,
#  'x--o--x--': 0.25,
#  'o-xxxoxoo': 1.0,
#  'x-oo-xoxx': 0.0,
#  'o-xx-ox-o': 0.6,
#  'x-oo-x--x': 0.8571428571428572,
#  'o-xx----o': 1.0,
#  'x--o----x': 0.0,
#  'xo--xox-o': 0.34834240475012357,
#  'xoxxoo-xo': 0.5,
#  '-xooxx-ox': 0.5,
#  '--xxoo-xo': 0.30285032362067865,
#  '---xo--xo': 0.25,
#  '---ox---x': 0.75,
#  'x-ox-xo-o': 0.08333333333333334,
#  'x-o--xo--': 0.0,
#  'o-x---x--': 0.6363636363636365,
#  'x-o-x-o--': 0.0,
#  'o-o-xoxxx': 1.0,
#  'x-x-oxo-o': 0.0,
#  '--x--xo-o': 0.0,
#  '--o---x-x': 0.8606557377049179,
#  '--x---o--': 0.11201298701298706,
#  'o-x-x-xo-': 1.0,
#  'x-o---ox-': 0.0,
#  'ooxxxxxoo': 1.0,
#  'xxoo-ooxx': 0.0,
#  'ooxx-xx-o': 0.5,
#  'xxoo--o-x': 0.0,
#  'o-xx--x-o': 0.33333333333333337,
#  'x--o--o-x': 0.12019914651493599,
#  '------o-x': 0.11495844875346246,
#  'x-ox--o--': 0.0,
#  'x-oox-o-x': 1.0,
#  'x-o---o-x': 0.4444444444444444,
#  'xoxxo-oxo': 0.5,
#  'xo-xo-ox-': 0.25,
#  'ox-ox-x--': 0.5,
#  'xo-x--o--': 0.33333333333333337,
#  'ox----x--': 0.5555555555555556,
#  'oxxxxoxoo': 1.0,
#  'xooo-xoxx': 0.0,
#  'oxxx-oxo-': 0.5416666666666667,
#  'x-oo-xox-': 0.0,
#  'o-xx--xo-': 0.75,
#  'x--o--ox-': 0.04259259259259259,
#  'o--x--x--': 0.4,
#  'xoxo-xoxo': 0.5,
#  'oxox-ox-x': 0.5,
#  'xoxo-xo--': 0.5,
#  'ox-x-ox--': 0.5,
#  'x--o-xo--': 0.75,
#  'oxoxoxxox': 0.5,
#  'xoxoxoox-': 0.5,
#  'oxox-xxo-': 0.5,
#  'xoxo--ox-': 0.5,
#  'oxox--x--': 0.25,
#  'x-xo--o--': 0.75,
#  'x-o-x-oox': 1.0,
#  'oxxxo-o-x': 0.5,
#  'xooox-x--': 0.5087509944311857,
#  'oxxxo----': 0.011904761904761915,
#  'xo-ox----': 0.519130477165279,
#  '-x-xo----': 0.49082698278295334,
#  'oxxox-xo-': 1.0,
#  'xooxo--x-': 0.0,
#  'oxxox----': 0.33333333333333337,
#  'x-oxo----': 0.3333333333333333,
#  '--xox----': 0.8749999999999999,
#  'o-oxoxx--': 0.0,
#  'x-xoxo---': 1.0,
#  '--oxox---': 0.0,
#  'x--xo-xoo': 1.0,
#  '---ox-oxx': 0.0,
#  '---xo-oxx': 0.0,
#  'xox-xoxoo': 1.0,
#  'oxo-ox-xx': 0.0,
#  'xox-xo-o-': 1.0,
#  'oxo--x-x-': 0.0,
#  'xox--o---': 0.5542573491331477,
#  'ox---x---': 0.0,
#  'oo-xx----': 0.0,
#  'xx--o----': 0.498077931154991,
#  'xo-ooxoxx': 0.0,
#  'ox-xxoxo-': 0.5384615384615385,
#  'xo-oox-x-': 0.0,
#  'ox-xxo---': 1.0,
#  'xo-o-x---': 0.0,
#  'xo-------': 0.0,
#  'xoooxxxo-': 0.5,
#  'oxxxo-ox-': 0.017857142857142863,
#  'xo-ox-xo-': 0.5,
#  '-x-xo-ox-': 0.020833333333333336,
#  '-o-ox-x--': 0.5051457975986284,
#  '-o----x--': 0.42270531400966205,
#  'oxo-o-xxx': 1.0,
#  'xox-x--oo': 0.0,
#  'oxo----xx': 1.0,
#  'xox----o-': 0.0,
#  '-ox------': 0.22664324100868133,
#  'ooxx-oxxo': 0.0,
#  'xxoo-x-ox': 0.75,
#  '-oxx-o-xo': 0.0,
#  '-x-o-x-ox': 0.5,
#  '-o-x---xo': 0.0,
#  '-x-----ox': 0.558219178082192,
#  '-o-----x-': 0.4626334519572957,
#  '-xxoo-oxx': 0.0,
#  '-o-xx-xoo': 1.0,
#  '-o-xx--o-': 0.9384615384615385,
#  '-o-x-----': 0.15591397849462357,
#  'oxoo--xxx': 1.0,
#  'xoxx--o-o': 0.0,
#  '-xoo--x-x': 0.7142857142857143,
#  '-oxx--o--': 0.0,
#  'ooxxxoxo-': 1.0,
#  'xxooox-x-': 0.0,
#  'ooxxx--o-': 1.0,
#  'xxo-o--x-': 0.0,
#  'oox-x----': 0.5088639421707569,
#  'xxoox-oox': 1.0,
#  'ooxx--xxo': 0.0,
#  'xx-o--oox': 1.0,
#  'oo-x--xx-': 0.0,
#  'xx-o--o--': 0.8,
#  '-oxxxxo-o': 1.0,
#  '-xo-oox-x': 0.0,
#  '-ox-xxo--': 0.8333333333333334,
#  '-xo-o-x--': 0.0,
#  'xxoxo-xoo': 1.0,
#  'oox-x-oxx': 0.0,
#  'xxo-o-xo-': 0.506581352833638,
#  'o-x-x-ox-': 0.006172839506172844,
#  'x-o-o-x--': 0.499000278806704,
#  'xox-xooxo': 0.5,
#  'oxo-oxx-x': 0.5,
#  'xox-xoo--': 0.5137987313712675,
#  'xo--x-o--': 0.4973359973359975,
#  'x-oox--ox': 1.0,
#  '---xo--x-': 0.4929396662387676,
#  '-xoox-ox-': 1.0,
#  '--xxo-xo-': 0.0,
#  '--xoxox-o': 1.0,
#  '--oxox--x': 0.0,
#  'oo-xxxxoo': 1.0,
#  'xx--oooxx': 0.0,
#  'x---o-oxx': 0.0,
#  'xxx-ooxoo': 1.0,
#  'oo--xxoxx': 0.0,
#  'xx--oox-o': 0.20689655172413793,
#  '-x--o-x-o': 0.0730593607305936,
#  '----x-o-x': 0.5039222726333088,
#  '-oxoxoxox': 1.0,
#  '-xoxox-xo': 0.0,
#  '-oxoxo--x': 0.75,
#  '-xoxox---': 0.0,
#  '-ox-xo---': 0.5188769035532985,
#  'xooxooxxx': 1.0,
#  'oxxoxx-oo': 0.0,
#  'xo-xoo-xx': 0.6666666666666666,
#  'ox-oxx-o-': 0.020564887252646113,
#  'x--xoo-x-': 0.5007121379965186,
#  'o---xx-o-': 0.5049667579194358,
#  'x---o--x-': 0.499493948467087,
#  'o-xox-xo-': 1.0,
#  'x--xo-ox-': 0.0,
#  'o---x-xo-': 0.5016326530612234,
#  'x-xoo-oxx': 0.0,
#  '--oxx-xoo': 0.0740740740740741,
#  'xoxx-ooxo': 0.5,
#  'oxo--xxox': 0.5,
#  'xox--oox-': 0.5,
#  ...}

# %%
N

# %%
player.load_values("data/values/order-inf")
# player.playing_mode()
# player.training_mode()

# %%
# number of testing matches
num_test = 1000
# number of matches that finished in a draw
num_draw = 0

for n in trange(num_test):
    # reset board for new game
    board.reset()
    
    if random.random() < 0.5:
        # start in random location
        i = random.choices(range(board.get_nrow()))[0]
        j = random.choices(range(board.get_nrow()))[0]
        board.add(me, row=i, col=j)

    # assume the game will end in a draw
    num_draw += 1
    while not board.is_full():
        # RL agent chooses an action
        action = player.choose_action(board)
        # update board
        board.add(sign=agent, row=action[0], col=action[1])
        # check if RL agent won
        if board.is_won(): 
            num_draw -= 1
            break
        # if nobody won yet, inverse the board
        board.inverse()

print("Finished testing")
print('   number of draws : ', num_draw, " of ", num_test)

# %% [markdown]
# ### Play against it

# %%
board.reset()

# %%
if board.is_full():
    board.reset()
    
# None or array [row,col]
my_pos = [2,1]
if my_pos:
    board.add(me, row=my_pos[0], col=my_pos[1])

if (not board.is_full()) and (not board.is_won()):
    # player 'x' plays
    board = player.play(board)

board.print()

# %%
print(player.get_value('o---x-ox-'))
print(player.get_value('o-oxx----'))
print(player.get_value('-xo-x---o'))
print(player.get_value('----xxo-o'))

print(player.get_value('ox--x-o--'))
print(player.get_value('---xx-o-o'))
print(player.get_value('--o-x--xo'))
print(player.get_value('o-o-xx---'))

# %%
# for order = 0 expect value = 0.333
# for order = 1 expect value = 0.233
# for order = 2 expect value = 0.106

print(player.get_value('x-o-xx-oo'))
print(player.get_value('--xox-oxo'))
print(player.get_value('oo-xx-o-x'))
print(player.get_value('oxo-xox--'))

print(player.get_value('o-xxx-oo-'))
print(player.get_value('x---xooxo'))
print(player.get_value('-oo-xxx-o'))
print(player.get_value('oxoox---x'))

# %%
# for order = 0 expect value = 0.75
# for order = 1 expect value = 0.5
# for order = 2 expect value = 0.5

print(player.get_value('o-xxoo-xx'))
print(player.get_value('-xoxo-xox'))
print(player.get_value('xx-ooxx-o'))
print(player.get_value('xox-oxox-'))

print(player.get_value('x-oooxxx-'))
print(player.get_value('ox--oxxox'))
print(player.get_value('-xxxooo-x'))
print(player.get_value('xoxxo--xo'))

# %%
# for order = 0 expect value = 0

print(player.get_value('xxooxx-oo'))

# %%
dico = {'a':1, 'b':2}

dico['a'] += dico.get('a', 0) + 1

print(dico)
